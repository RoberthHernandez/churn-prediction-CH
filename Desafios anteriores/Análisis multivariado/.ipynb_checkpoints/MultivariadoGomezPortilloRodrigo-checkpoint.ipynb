# %% [markdown]
# # Importación de librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importación del dataset

# %%
churn_data_set = pd.read_csv("..\Data\Churn Prediction.csv",delimiter = ";",index_col=0)
churn_data_set.drop('Surname', inplace = True, axis = 1)
churn_data_set.drop('Id', inplace = True, axis = 1)
churn_data_set.head()
# Out:
#      Score Nationality  Gender  Age  Tenure    Balance  Products  Card  \
# Row
# 1      619      France  Female   42       2       0.00         1     1
# 2      608       Spain  Female   41       1   83807.86         1     0
# 3      502      France  Female   42       8  159660.80         3     1
# 4      699      France  Female   39       1       0.00         2     0
# 5      850       Spain  Female   43       2  125510.82         1     1
#
#      Active     Salary  Exited
# Row
# 1         1  101348.88       1
# 2         1  112542.58       0
# 3         0  113931.57       1
# 4         0   93826.63       0
# 5         1   79084.10       0

# %% [markdown]
# ## Análisis dataset

# %%
churn_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Score        10000 non-null  int64
#  1   Nationality  10000 non-null  object
#  2   Gender       10000 non-null  object
#  3   Age          10000 non-null  int64
#  4   Tenure       10000 non-null  int64
#  5   Balance      10000 non-null  float64
#  6   Products     10000 non-null  int64
#  7   Card         10000 non-null  int64
#  8   Active       10000 non-null  int64
#  9   Salary       10000 non-null  float64
#  10  Exited       10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 937.5+ KB

# %%
churn_data_set.describe().T
# Out:
#             count           mean           std     min       25%         50%  \
# Score     10000.0     650.528800     96.653299  350.00    584.00     652.000
# Age       10000.0      38.921800     10.487806   18.00     32.00      37.000
# Tenure    10000.0       5.012800      2.892174    0.00      3.00       5.000
# Balance   10000.0   76485.889288  62397.405202    0.00      0.00   97198.540
# Products  10000.0       1.530200      0.581654    1.00      1.00       1.000
# Card      10000.0       0.705500      0.455840    0.00      0.00       1.000
# Active    10000.0       0.515100      0.499797    0.00      0.00       1.000
# Salary    10000.0  100090.239881  57510.492818   11.58  51002.11  100193.915
# Exited    10000.0       0.203700      0.402769    0.00      0.00       0.000
#
#                   75%        max
# Score        718.0000     850.00
# Age           44.0000      92.00
# Tenure         7.0000      10.00
# Balance   127644.2400  250898.09
# Products       2.0000       4.00
# Card           1.0000       1.00
# Active         1.0000       1.00
# Salary    149388.2475  199992.48
# Exited         0.0000       1.00

# %% [markdown]
# # Análisis bivariado

# %%
plt.rcParams['figure.figsize'] = (20, 15)

sns.heatmap(churn_data_set.drop(labels = ['Products','Card','Active','Tenure'] ,axis = 1).corr(), annot = True, cmap = 'Wistia')
plt.title('Heatmap for the Dataset', fontsize = 20)
plt.show()

# %% [markdown]
# # Análisis Multivariado

# %%
#Pairplot
sns.pairplot(churn_data_set,hue = 'Exited'  , palette = 'Set2', vars = ['Balance', 'Salary','Age',]);

# %% [markdown]
# Del gráfico anterior se puede observar que la gente de menor edad es menos propensa a desertar.

# %% [markdown]
# ## Análisis de la nacionalidad

# %%
churn_data_set.groupby('Nationality').size().reset_index(name='counts')
# Out:
#   Nationality  counts
# 0      France    5014
# 1     Germany    2509
# 2       Spain    2477

# %%
sns.boxplot(x='Nationality',y="Salary", hue = 'Exited',data=churn_data_set,palette=['#008B8B','#00FFFF'])
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='Salary'>

# %%
## Tengo en cuenta aquellos balances que no están en cero para tener una mejor visualización
sns.boxplot(x='Nationality',y="Balance", hue = 'Exited',data=churn_data_set.loc[churn_data_set['Balance'] != 0],palette=['#008B8B','#00FFFF'])
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='Balance'>

# %% [markdown]
# - Es importante tener en cuenta que los franceses representan el 50% del dataset.
# - No parece que haya una realción apreciable entre los paises y la situación económica con la deserción
#
# Hay una tendencia en Francia y
